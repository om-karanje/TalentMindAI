# %% [markdown]
# # TalentMindAI Semantic Testing
#
# Workflow for Person 2: load JD and candidates, parse JD intent, generate candidate intelligence, score, rank, and inspect explanations.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.data_loader import load_candidates, load_job_description
from src.jd_parser import parse_jd
from src.jd_intelligence import extract_jd_intelligence
from src.candidate_intelligence import extract_candidate_intelligence
from src.candidate_text import candidate_to_text
from src.semantic_matcher import rank_candidates
from src.utils import setup_logging

setup_logging(debug=True)

# %%
jd_text = load_job_description()
candidates = load_candidates()
len(candidates), jd_text[:300]

# %%
parsed_jd = parse_jd(jd_text)
jd_intelligence = extract_jd_intelligence(jd_text)
parsed_jd, jd_intelligence

# %%
sample = candidates[0]
candidate_to_text(sample)[:1000], extract_candidate_intelligence(sample)

# %%
ranked = rank_candidates(jd_text, candidates)
[(item['rank'], item['candidate_id'], item['semantic_score'], item['matched_domains'], item['reason_for_match']) for item in ranked]
